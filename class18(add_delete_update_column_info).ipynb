# %%
import pandas as pd
import pandera as pa
import numpy as np
from nptyping import NDArray, Shape, Int64

# %% [markdown]
# # Dataframe
#
# * add new columns
#     *one column
#     *two or more columns
# * delete columns
# * change data type of columns
# * map
# * apply
#     * on one column
#     * more than one column
# * concat
#     *axis
#         *axis = 0 (top to bottom)
#         *axis = 1 (left to rigth)
#
# * describe dataframe
#     *df.info() # total index, columns, names and data type, total fill cells
#     *df.describe() # mean, std, min # statistical properties | apply only numeric values
#     *df.head() # first 5 rows
#     *df.tail() # last 5 rows

# %%
total : int = 10000
s1 : NDArray[Shape[str(total)], Int64] = np.random.randint(80,100, total)
print(len(s1))
s1
# Out:
# 10000
# array([90, 98, 98, ..., 99, 93, 93])

# %%
total : int = 10000
s1 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(80,100, (total,5))
ss1 :pd.DataFrame = pd.DataFrame(s1, columns=["s1","s2","s3","s4","s5"])

s2 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(70,79, (total,5))
ss2 :pd.DataFrame = pd.DataFrame(s2, columns=["s1","s2","s3","s4","s5"])

s3 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(60,69, (total,5))
ss3 :pd.DataFrame = pd.DataFrame(s3, columns=["s1","s2","s3","s4","s5"])

s4 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(50,59, (total,5))
ss4 :pd.DataFrame = pd.DataFrame(s4, columns=["s1","s2","s3","s4","s5"])

s5 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(40,49, (total,5))
ss5 :pd.DataFrame = pd.DataFrame(s5, columns=["s1","s2","s3","s4","s5"])

s6 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(33,39, (total,5))
ss6 :pd.DataFrame = pd.DataFrame(s6, columns=["s1","s2","s3","s4","s5"])

s7 : NDArray[Shape[str(total)+"5"], Int64] = np.random.randint(0,32, (total,5))
ss7 :pd.DataFrame = pd.DataFrame(s7, columns=["s1","s2","s3","s4","s5"])


print(len(ss1))
print(len(ss2))
print(len(ss3))
print(len(ss4))
print(len(ss5))
print(len(ss6))
print(len(ss7))

s1
# Out:
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# 10000
# array([[89, 92, 98, 82, 93],
#        [83, 99, 91, 83, 82],
#        [94, 92, 86, 98, 89],
#        ...,
#        [92, 98, 88, 93, 80],
#        [85, 98, 84, 86, 92],
#        [97, 84, 85, 98, 91]])

# %%
ss1
# Out:
#       s1  s2  s3  s4  s5
# 0     89  92  98  82  93
# 1     83  99  91  83  82
# 2     94  92  86  98  89
# 3     84  90  86  90  92
# 4     87  82  98  80  98
# ...   ..  ..  ..  ..  ..
# 9995  95  98  87  87  90
# 9996  81  98  83  86  99
# 9997  92  98  88  93  80
# 9998  85  98  84  86  92
# 9999  97  84  85  98  91
#
# [10000 rows x 5 columns]

# %%
ss2
# Out:
#       s1  s2  s3  s4  s5
# 0     76  70  76  74  74
# 1     76  75  78  76  70
# 2     74  72  74  76  78
# 3     70  75  75  75  75
# 4     77  77  71  73  76
# ...   ..  ..  ..  ..  ..
# 9995  78  70  72  72  76
# 9996  75  77  75  78  73
# 9997  76  75  78  73  76
# 9998  74  78  73  77  70
# 9999  77  77  71  77  73
#
# [10000 rows x 5 columns]

# %%
ss3
# Out:
#       s1  s2  s3  s4  s5
# 0     63  65  64  61  65
# 1     63  60  64  63  64
# 2     65  64  60  61  68
# 3     63  60  65  60  63
# 4     63  67  67  63  61
# ...   ..  ..  ..  ..  ..
# 9995  65  66  67  65  65
# 9996  65  64  64  65  67
# 9997  67  61  62  65  60
# 9998  66  64  68  68  67
# 9999  63  65  66  65  68
#
# [10000 rows x 5 columns]

# %%
df : pd.DataFrame = pd.concat([ss1,ss2,ss3,ss4,ss5,ss6,ss7])

display(df.info())
print("=========")

display(df.describe())
print("=========")

display(df.head())
print("=========")

display(df.tail())
print("=========")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   s1      70000 non-null  int32
#  1   s2      70000 non-null  int32
#  2   s3      70000 non-null  int32
#  3   s4      70000 non-null  int32
#  4   s5      70000 non-null  int32
# dtypes: int32(5)
# memory usage: 1.9 MB
# None
# =========
#                  s1            s2            s3            s4            s5
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean      53.807843     53.809257     53.770729     53.787486     53.758271
# std       23.392220     23.371685     23.428586     23.352817     23.363054
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       37.000000     37.000000     37.000000     37.000000     37.000000
# 50%       54.000000     54.000000     54.000000     54.000000     54.000000
# 75%       72.000000     72.000000     72.000000     72.000000     72.000000
# max       99.000000     99.000000     99.000000     99.000000     99.000000
# =========
#    s1  s2  s3  s4  s5
# 0  89  92  98  82  93
# 1  83  99  91  83  82
# 2  94  92  86  98  89
# 3  84  90  86  90  92
# 4  87  82  98  80  98
# =========
#       s1  s2  s3  s4  s5
# 9995   6  21  27  21   2
# 9996   6  10  27  28   5
# 9997  11  14   0  12  16
# 9998   3  16  30  21  24
# 9999   1  30  15   3  30
# =========

# %%
df.to_csv("student.csv", index=False)

# %%
df1 : pd.DataFrame = pd.read_csv("./student.csv")
df1.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  89  92  98  82  93
# 1  83  99  91  83  82
# 2  94  92  86  98  89
# 3  84  90  86  90  92
# 4  87  82  98  80  98

# %% [markdown]
# # apply operations on columns
#     * Extract one column from DataFrame
#         * dataframe['column']
#             * add new column
#             * get column with space between columns text
#         * dataframe.column
#             * not add new column
#             * not get column with space between column text
#     * Extract two or more columns from DataFrame
#         * dataframe[['column1', 'column2']]
#             * pass list into Dataframe

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  89  92  98  82  93
# 1  83  99  91  83  82
# 2  94  92  86  98  89
# 3  84  90  86  90  92
# 4  87  82  98  80  98

# %%
df['s5']
# Out:
# 0        93
# 1        82
# 2        89
# 3        92
# 4        98
#          ..
# 69995     2
# 69996     5
# 69997    16
# 69998    24
# 69999    30
# Name: s5, Length: 70000, dtype: int64

# %%
df.s1
# Out:
# 0        89
# 1        83
# 2        94
# 3        84
# 4        87
#          ..
# 69995     6
# 69996     6
# 69997    11
# 69998     3
# 69999     1
# Name: s1, Length: 70000, dtype: int64

# %%
df[["s1","s2","s3","s4","s5"]]
# Out:
#        s1  s2  s3  s4  s5
# 0      89  92  98  82  93
# 1      83  99  91  83  82
# 2      94  92  86  98  89
# 3      84  90  86  90  92
# 4      87  82  98  80  98
# ...    ..  ..  ..  ..  ..
# 69995   6  21  27  21   2
# 69996   6  10  27  28   5
# 69997  11  14   0  12  16
# 69998   3  16  30  21  24
# 69999   1  30  15   3  30
#
# [70000 rows x 5 columns]

# %% [markdown]
# # Add new Column
#     * Addition operation on column

# %%
df.head()
# Out:
#    s1  s2  s3  s4  s5
# 0  89  92  98  82  93
# 1  83  99  91  83  82
# 2  94  92  86  98  89
# 3  84  90  86  90  92
# 4  87  82  98  80  98

# %%
df['Total'] = 500 # add new column
df['Total'] = 300 # update column value
del df['Total'] # delete column
df
# Out:
#        s1  s2  s3  s4  s5
# 0      89  92  98  82  93
# 1      83  99  91  83  82
# 2      94  92  86  98  89
# 3      84  90  86  90  92
# 4      87  82  98  80  98
# ...    ..  ..  ..  ..  ..
# 69995   6  21  27  21   2
# 69996   6  10  27  28   5
# 69997  11  14   0  12  16
# 69998   3  16  30  21  24
# 69999   1  30  15   3  30
#
# [70000 rows x 5 columns]

# %%
df.Total = 500 # update column value
# df['Total'] = 300 # update column value
del df.Total = 300 # delete column
df
# Out:
#   Cell In[44], line 3
#     del df.Total = 300 # delete column
#                  ^
# SyntaxError: invalid syntax

# %%
s1
# Out:
# array([[89, 92, 98, 82, 93],
#        [83, 99, 91, 83, 82],
#        [94, 92, 86, 98, 89],
#        ...,
#        [92, 98, 88, 93, 80],
#        [85, 98, 84, 86, 92],
#        [97, 84, 85, 98, 91]])

# %%
df['s1'] + df["s2"]+ df["s3"]+ df["s4"]+ df["s5"]
# Out:
# 0        454
# 1        438
# 2        459
# 3        442
# 4        445
#         ...
# 69995     77
# 69996     76
# 69997     53
# 69998     94
# 69999     79
# Length: 70000, dtype: int64

# %%
display(df.head())
# Out:
#    s1  s2  s3  s4  s5
# 0  89  92  98  82  93
# 1  83  99  91  83  82
# 2  94  92  86  98  89
# 3  84  90  86  90  92
# 4  87  82  98  80  98

# %%
print(89+89 )
df["s1"] + df["s2"]+ df["s3"]+ df["s4"]+ df["s5"]
# Out:
# 178
# 0        454
# 1        438
# 2        459
# 3        442
# 4        445
#         ...
# 69995     77
# 69996     76
# 69997     53
# 69998     94
# 69999     79
# Length: 70000, dtype: int64

# %%
df["obtained"] = df["s1"] + df["s2"]+ df["s3"]+ df["s4"]+ df["s5"]
df
# Out:
#        s1  s2  s3  s4  s5  obtained
# 0      89  92  98  82  93       454
# 1      83  99  91  83  82       438
# 2      94  92  86  98  89       459
# 3      84  90  86  90  92       442
# 4      87  82  98  80  98       445
# ...    ..  ..  ..  ..  ..       ...
# 69995   6  21  27  21   2        77
# 69996   6  10  27  28   5        76
# 69997  11  14   0  12  16        53
# 69998   3  16  30  21  24        94
# 69999   1  30  15   3  30        79
#
# [70000 rows x 6 columns]

# %%
df["obtained"] = df["s1"] + df["s2"]+ df["s3"]+ df["s4"]+ df["s5"]
df["percentage"] = df["obtained"] / df["Total"] * 100
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Anaconda\envs\python12\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 2
#       1 df["obtained"] = df["s1"] + df["s2"]+ df["s3"]+ df["s4"]+ df["s5"]
# ----> 2 df["percentage"] = df["obtained"] / df["Total"] * 100
#       3 df
#
# File d:\Anaconda\envs\python12\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File d:\Anaconda\envs\python12\Lib\site-packages\pandas\core\indexes\base.py:3809, in Index.get_loc(self, key)
#    3804     if isinstance(casted_key, slice) or (
#    3805         isinstance(casted_key, abc.Iterable)
#    3806         and any(isinstance(x, slice) for x in casted_key)
#    3807     ):
#    3808         raise InvalidIndexError(key)
# -> 3809     raise KeyError(key) from err
#    3810 except TypeError:
#    3811     # If we have a listlike key, _check_indexing_error will raise
#    3812     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3813     #  the TypeError.
#    3814     self._check_indexing_error(key)
#
# KeyError: 'Total'
